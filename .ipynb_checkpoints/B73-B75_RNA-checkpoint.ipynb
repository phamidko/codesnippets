# %%
import pandas as pd
#import numpy as np
#import statsmodels.api as sm
#import statsmodels.formula.api as smf

#import pzfxlib as pz
#from openpyxl import Workbook
#from openpyxl.utils import get_column_letter

# %%
#paste Mouse Grouping as you defines structure in Prism
group_columns = ['Group','id']
B75_group_tbl = pd.read_csv("B75-group.csv", 
                        sep=',',
                       dtype={"group":str, "id":str})
B75_group_tbl
# Out:
#                  Group  id
# 0                  HIV   7
# 1                  HIV  11
# 2                  HIV  14
# 3                  HIV  17
# 4          HIV + Tumor   4
# 5          HIV + Tumor   8
# 6          HIV + Tumor  12
# 7          HIV + Tumor  15
# 8          HIV + tumor  18
# 9          HIV + Tumor  20
# 10            HIV only   3
# 11          Tumor only   6
# 12          Tumor only  10
# 13          Tumor only  13
# 14          Tumor only  16
# 15          Tumor only   2
# 16  Uninfected Control   1
# 17  Uninfected Control   5
# 18  Uninfected Control   9
# 19  Uninfected Control  19

# %%
B73_group_tbl = pd.read_csv("B73-group.csv", 
                        sep=',',
                       dtype={"group":str, "id":str})
B73_group_tbl

# %%
flow_df = pd.read_clipboard(sep='\t')
flow_df

# %%
flow_df= flow_df.dropna(subset=['TUBE NAME'])
df_merge_col = pd.merge(group_tbl, flow_df, left_on='id',right_on='TUBE NAME',how='left')
df_merge_col.to_clipboard(sep='\t')
df_merge_col.shape
